# %% [markdown]
# # Download NAIP Imagery
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/download_naip.ipynb)
#
# ## Install package
#
# To use the `geoai-py` package, ensure it is installed in your environment. Uncomment the command below if needed.

# %%
 # %pip install geoai-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.6/269.6 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.5/122.5 kB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.4/618.4 kB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 99.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 71.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 86.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 117.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.3/605.3 kB 52.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 31.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Import library

# %%
import geoai

# %% [markdown]
# ## Create an interactive map

# %%
m = geoai.LeafMap(center=[47.031260, -99.156360], zoom=14)
m.add_basemap("Esri.WorldImagery")
m
# Out:
# LeafMap(center=[47.03126, -99.15636], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_titl…

# %% [markdown]
# Use the drawing tool to select an area of interest (AOI) on the map. The selected area will be used to search for NAIP imagery.

# %%
if m.user_roi is not None:
    bbox = m.user_roi_bounds()
else:
    bbox = [-99.1705, 47.0149, -99.1296, 47.0365]

# %% [markdown]
# ## Search for NAIP imagery

# %%
download_files = geoai.download_naip(
    bbox = bbox,
    output_dir= "naip_data",
    max_items=1,
    year=2022
)
# Out:
# Found 1 NAIP items.
# ...
# m_3907606_ne_18_060_20220720.tif: 100%|██████████| 369M/369M [01:30<00:00, 4.29MiB/s]
# Successfully saved to naip_data/m_3907606_ne_18_060_20220720.tif

# %%
items = geoai.pc_stac_search(
    collection="naip",
    bbox=bbox
)
# Out:
# Found 12 items matching search criteria

# %%
items
# Out:
# [<Item id=pa_m_3907606_ne_18_060_20220720>,
#  <Item id=pa_m_3907607_nw_18_060_20220517>,
#  <Item id=pa_m_3907607_nw_18_060_20191011_20191203>,
#  <Item id=pa_m_3907606_ne_18_060_20191011_20191203>,
#  <Item id=pa_m_3907607_nw_18_1_20170609_20171207>,
#  <Item id=pa_m_3907606_ne_18_1_20170608_20171207>,
#  <Item id=pa_m_3907607_nw_18_1_20150522_20151201>,
#  <Item id=pa_m_3907606_ne_18_1_20150522_20151201>,
#  <Item id=pa_m_3907607_nw_18_1_20130605_20130923>,
#  <Item id=pa_m_3907606_ne_18_1_20130605_20130923>,
#  <Item id=pa_m_3907607_nw_18_1_20100704>,
#  <Item id=pa_m_3907606_ne_18_1_20100704>]

# %% [markdown]
# ## Visualize the search results

# %%
geoai.view_pc_items(items=items)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
# ...

# %% [markdown]
# ## Download NAIP imagery

# %%
geoai.pc_stac_download(items, output_dir="naip", assets=["image"], year =)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3929507311.py in <cell line: 0>()
# ----> 1 geoai.pc_stac_download(items, output_dir="naip", assets=["image"], year = 2022)
#
# TypeError: pc_stac_download() got an unexpected keyword argument 'year'
